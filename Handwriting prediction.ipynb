# %%
from sklearn.cluster import KMeans
import numpy as np
import csv
import math
import matplotlib.pyplot
import pandas as pd
from matplotlib import pyplot as plt

# %%
trainingPercent = 80
testingPercent = 20
epoch = 100
learningRate = 0.2

# %%
def getData(filename):
    df = pd.read_csv(filename)
    return df

# %%
def prediction(w,x,b)
    y = w.T * x + b
    return y

# %%
def subDf(df1,df2):
    df = df
# Out:
#        img_id_A img_id_B  target  f1_x  f2_x  f3_x  f4_x  f5_x  f6_x  f7_x  \
# 0         0359a    0359b       1     2     1     1     0     2     2     0
# 1         1468a    0359b       0     1     1     1     2     2     2     0
# 2         1483a    0359b       0     2     1     1     3     2     3     0
# 3         1488a    0359b       0     1     1     1     0     2     3     0
# 4         1534c    0359b       0     3     1     1     0     2     1     0
# 5         0491b    0359b       0     2     1     1     0     2     1     1
# 6         1119a    0359b       0     1     1     1     0     0     2     0
# 7         1129c    0359b       0     1     2     1     3     2     2     0
# 8         1344a    0359b       0     1     1     1     0     2     3     0
# 9         1516a    0359b       0     2     0     1     0     2     2     1
# 10        0306a    0359b       0     3     1     1     2     2     2     0
# ...

# %%
def combineDf(top,bot):
    df = pd.concat([top, bot])
    return df

# %%
def shuffleRows(df):            # Shuffle rows to get randomize rows of data for training and testing
    shuffled = df.sample(frac=1).reset_index(drop=True)
    return shuffled

# %%
def lostFunction():

# %%
#normalize?
#cost function? RMSE
#GD     
right = getData('HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/same_pairs.csv')
feature = getData('HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/HumanObserved-Features-Data.csv')
feature = feature.iloc[:, 1:]
top = getData('HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/same_pairs.csv')
bot = getData('HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/diffn_pairs.csv')
df = combineDf(top, bot)
feature.rename(columns={'img_id': 'img_id_A'}, inplace=True) 
result = pd.merge(df, feature, on = ['img_id_A'])
feature.rename(columns={'img_id_A': 'img_id_B'}, inplace=True)
result = pd.merge(result, feature, on = ['img_id_B'])
result

# %% [markdown]
# Logistic Regression

# %%
#0-1
#
